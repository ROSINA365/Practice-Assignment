# %%
# Import required packages
import pandas as pd
import numpy as np
import json
import dash
from dash import dcc
from dash import html
import plotly.express as px
import plotly.graph_objs as go
from dash.dependencies import Input, Output

# %%
# Add Dataframe
df = pd.DataFrame({
    "Fruit": ["Apples", "Oranges", "Bananas", "Apples", "Oranges", "Bananas"],
    "Amount": [4, 1, 2, 2, 4, 5],
    "City": ["San Francisco", "San Francisco", "San Francisco", "New York City", "Montréal", "New York City"]
})

# Add a bar graph figure
#fig = px.bar(df, x="Fruit", y="Amount", color="City", barmode="group")


app = dash.Dash()
app.layout = html.Div(children=[
    html.H1(
        children='Dashboard',
        style={
            'textAlign': 'center'
        }
    ), 
    # Create dropdown
     html.Div([
    dcc.Dropdown(['New York City', 'Montréal', 'San Francisco'], 'New York City')
]), 
    # Bar graph
    dcc.Graph(
        id='example-graph-2',
        figure={
            'data': df,
            'layout': go.Layout(title='Order Status by city', barmode='group')
        })
   ])

# Run Application
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [21/Sep/2022 11:15:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Sep/2022 11:15:27] "GET /_dash-dependencies HTTP/1.1" 200 -
# Exception on /_dash-layout [GET]
# Traceback (most recent call last):
# ...

# %%
df = pd.DataFrame({
    "Fruit": ["Apples", "Oranges", "Bananas", "Apples", "Oranges", "Bananas"],
    "Amount": [4, 1, 2, 2, 4, 5],
    "City": ["San Francisco", "San Francisco", "San Francisco", "New York City", "Montréal", "New York City"]
})

# Add a bar graph figure
#fig = go.bar(df, x="Fruit", y="Amount", color="City", barmode="group")

# Bar graph
   
app = dash.Dash()

app.layout =  html.Div(children=[
    html.H1(
        children='Dashboard',
        style={
            'textAlign': 'center'
        }
    ), 
    # Create dropdown
     html.Div([
    dcc.Dropdown(['New York City', 'Montréal', 'San Francisco'], 'New York City')
]),
dcc.Graph(
        id='example-graph-2',
        figure={
            'data': df,
            'layout':
            go.Layout(title='Order Status by city', barmode='group')
        })
]) 
# Run Application
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [21/Sep/2022 11:32:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Sep/2022 11:32:45] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_6_1m1663187175.js HTTP/1.1" 200 -
# ...

# %%
df = pd.DataFrame({
    "Fruit": ["Apples", "Oranges", "Bananas", "Apples", "Oranges", "Bananas"],
    "Amount": [4, 1, 2, 2, 4, 5],
    "City": ["San Francisco", "San Francisco", "San Francisco", "New York City", "Montréal", "New York City"]
})
df
# Out:
#      Fruit  Amount           City
# 0   Apples       4  San Francisco
# 1  Oranges       1  San Francisco
# 2  Bananas       2  San Francisco
# 3   Apples       2  New York City
# 4  Oranges       4       Montréal
# 5  Bananas       5  New York City
